# %% [markdown]
# # Project: Breast Cancer Detection Using Machine Learning Classifier

# %% [markdown]
# # Goal of the Project:
# We have extracted features of breast cancer patient cells and normal person cells. As a Machine learning engineer / Data Scientist has to create an ML model to classify malignant and benign tumor. To complete this ML project we are using the supervised machine learning classifier algorithm.

# %% [markdown]
# 0 means malignant tumor
# 1 mean benign tumor

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 

#import warnings
#warnings.filterwarnings("ignore")

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv("cancer_classification.csv")

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df.tail()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
# ...

# %%
df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %%
# Information of cancer Dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %% [markdown]
# # Data Visualization

# %%
# Paiplot of cancer dataframe

#sns.pairplot(df, hue = 'target')

# %%
# pair plot of sample feature
#sns.pairplot(df, hue = 'target', 
            # vars = ['mean radius', 'mean texture', 'mean perimeter', 'mean area', 'mean smoothness'] )

# %% [markdown]
# The pair plot showing malignant and benign tumor data distributed in two classes. It is easy to differentiate in the pair plot.

# %%
# counplot
#sns.countplot(df["target"])

# %% [markdown]
# In the below counterplot max samples mean radius is equal to 1.

# %%
#countplot for feature mean radius
#plt.figure(figsize=(20,8))
#sns.countplot(df["mean radius"])

# %%
#Heatmap
#plt.figure(figsize=(16,9))
#sns.heatmap(df)

# %% [markdown]
# In the below heatmap we can see the variety of different feature’s value. The value of feature ‘mean area’ and ‘worst area’ are greater than other and ‘mean perimeter’, ‘area error’, and ‘worst perimeter’ value slightly less but greater than remaining features.

# %%
#Heatmap of a correlation matrix
#plt.figure(figsize=(20,20))
#sns.heatmap(df.corr(),annot=True,cmap="coolwarm",linewidths = 2)

# %% [markdown]
# To find a correlation between each feature and target we visualize heatmap using the correlation matrix.

# %% [markdown]
# # Data Preprocessing

# %%
#Split DataFrame in train and test

# %%
x = df.drop(["target"],axis=1)
x.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
y = df['target']
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %%
# split dataset into train and test

from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y, test_size=0.2,random_state=5)

# %%
xtrain
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 306       13.200         15.82           84.07      537.3          0.08511
# 410       11.360         17.57           72.49      399.8          0.08858
# 197       18.080         21.84          117.40     1024.0          0.07371
# 376       10.570         20.22           70.15      338.3          0.09073
# 244       19.400         23.50          129.10     1155.0          0.10270
# ..           ...           ...             ...        ...              ...
# 8         13.000         21.82           87.50      519.8          0.12730
# 73        13.800         15.79           90.43      584.1          0.10070
# 400       17.910         21.02          124.40      994.0          0.12300
# 118       15.780         22.91          105.70      782.6          0.11550
# 206        9.876         17.27           62.92      295.4          0.10890
#
# ...

# %%
xtest
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 28         15.30         25.27          102.40      732.4          0.10820
# 163        12.34         22.22           79.85      464.5          0.10120
# 123        14.50         10.89           94.28      640.7          0.11010
# 361        13.30         21.57           85.24      546.1          0.08582
# 549        10.82         24.21           68.89      361.6          0.08192
# ..           ...           ...             ...        ...              ...
# 414        15.13         29.81           96.71      719.5          0.08320
# 515        11.34         18.61           72.76      391.2          0.10490
# 186        18.31         18.58          118.60     1041.0          0.08588
# 3          11.42         20.38           77.58      386.1          0.14250
# 261        17.35         23.06          111.00      933.1          0.08662
#
# ...

# %%
ytrain
# Out:
# 306    1
# 410    1
# 197    0
# 376    1
# 244    0
#       ..
# 8      0
# 73     0
# 400    0
# 118    0
# 206    1
# Name: target, Length: 455, dtype: int64

# %%
ytest
# Out:
# 28     0
# 163    1
# 123    1
# 361    1
# 549    1
#       ..
# 414    0
# 515    1
# 186    0
# 3      0
# 261    0
# Name: target, Length: 114, dtype: int64

# %% [raw]
# # Feature Scaling

# %%
#Converting different units and magnitude data in one unit.

# %%
# Feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
xtrain_sc = sc.fit_transform(xtrain)
xtest_sc = sc.transform(xtest)

# %% [markdown]
# # Breast Cancer Detection Machine Learning Model Building

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %% [markdown]
# # Support vector Classifier

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(xtrain,ytrain)
ypred_svc = svc.predict(xtest)
accuracy_score(ytest, ypred_svc)
# Out:
# 0.9385964912280702

# %%
# Train with Standard scaled Data
svc_classifier = SVC()
svc_classifier.fit(xtrain_sc, ytrain)
ypred_svc_sc = svc_classifier.predict(xtest_sc)
accuracy_score(ytest, ypred_svc_sc)
# Out:
# 0.9649122807017544

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(xtrain,ytrain)
ypred_lr = lr.predict(xtest)
accuracy_score(ytest,ypred_lr)
# Out:
# 0.956140350877193

# %%
# Train with Standard scaled Data
lr_classifier = LogisticRegression(random_state = 51, penalty = 'l2')
lr_classifier.fit(xtrain_sc, ytrain)
ypred_lr_sc = lr_classifier.predict(xtest_sc)
accuracy_score(ytest, ypred_lr_sc)
# Out:
# 0.9736842105263158

# %% [markdown]
# # K – Nearest Neighbor Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5, metric="minkowski",p=2)
knn.fit(xtrain,ytrain)
ypred_knn = knn.predict(xtest)
accuracy_score(ytest,ypred_knn)
# Out:
# 0.9385964912280702

# %%
#train with standard scaled data
knn_classifier= KNeighborsClassifier(n_neighbors=5, metric="minkowski",p=2)
knn_classifier.fit(xtrain_sc,ytrain)
ypred_knn_sc = knn_classifier.predict(xtest_sc)
accuracy_score(ytest,ypred_knn_sc)
# Out:
# 0.9649122807017544

# %% [markdown]
# # Naive Bayes Classifer

# %%
# Naive Bayes Classifier
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(xtrain,ytrain)
ypred_nb = nb.predict(xtest)
accuracy_score(ytest,ypred_nb)
# Out:
# 0.9473684210526315

# %%
# Train with Standard scaled Data
nb_classifier = GaussianNB()
nb_classifier.fit(xtrain_sc, ytrain)
ypred_nb_sc = nb_classifier.predict(xtest_sc)
accuracy_score(ytest, ypred_nb_sc)
# Out:
# 0.9385964912280702

# %% [markdown]
# # Decision Tree Classifier

# %%
# Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
dt_classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 51)
dt_classifier.fit(xtrain, ytrain)
ypred_dt = dt_classifier.predict(xtest)
accuracy_score(ytest, ypred_dt)
# Out:
# 0.9473684210526315

# %%
# Train with Standard scaled Data
dt_classifier2 = DecisionTreeClassifier(criterion = 'entropy', random_state = 51)
dt_classifier2.fit(xtrain_sc, ytrain)
ypred_dt_sc = dt_classifier.predict(xtest_sc)
accuracy_score(ytest, ypred_dt_sc)
# Out:
# 0.7543859649122807

# %% [markdown]
# # Random Forest Classifier

# %%
# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators = 20, criterion = 'entropy', random_state = 51)
rf_classifier.fit(xtrain, ytrain)
ypred_rf = rf_classifier.predict(xtest)
accuracy_score(ytest, ypred_rf)
# Out:
# 0.9736842105263158

# %%
# Train with Standard scaled Data
rf_classifier2 = RandomForestClassifier(n_estimators = 20, criterion = 'entropy', random_state = 51)
rf_classifier2.fit(xtrain_sc, ytrain)
ypred_rf_sc = rf_classifier.predict(xtest_sc)
accuracy_score(ytest, ypred_rf_sc)
# Out:
# 0.7543859649122807

# %% [markdown]
# # Adaboost Classifier

# %%
# Adaboost Classifier
from sklearn.ensemble import AdaBoostClassifier
adb_classifier = AdaBoostClassifier(DecisionTreeClassifier(criterion = 'entropy', random_state = 200),
                                    n_estimators=2000,
                                    learning_rate=0.1,
                                    algorithm='SAMME.R',
                                    random_state=1,)
adb_classifier.fit(xtrain, ytrain)
ypred_adb = adb_classifier.predict(xtest)
accuracy_score(ytest, ypred_adb)
# Out:
# 0.9473684210526315

# %%
# Train with Standard scaled Data
adb_classifier2 = AdaBoostClassifier(DecisionTreeClassifier(criterion = 'entropy', random_state = 200),
                                    n_estimators=2000,
                                    learning_rate=0.1,
                                    algorithm='SAMME.R',
                                    random_state=1,)
adb_classifier2.fit(xtrain_sc, ytrain)
ypred_adb_sc = adb_classifier2.predict(xtest_sc)
accuracy_score(ytest, ypred_adb_sc)
# Out:
# 0.9473684210526315

# %% [markdown]
# # XGBoost Classifier

# %%
# XGBoost Classifier
from xgboost import XGBClassifier
xgb_classifier = XGBClassifier()
xgb_classifier.fit(xtrain, ytrain)
ypred_xgb = xgb_classifier.predict(xtest)
accuracy_score(ytest, ypred_xgb)
# Out:
# 0.9824561403508771

# %%
# Train with Standard scaled Data
xgb_classifier2 = XGBClassifier()
xgb_classifier2.fit(xtrain_sc, ytrain)
ypred_xgb_sc = xgb_classifier2.predict(xtest_sc)
accuracy_score(ytest, ypred_xgb_sc)
# Out:
# 0.9824561403508771

# %% [markdown]
# # Confusion Matrix

# %%
#cm = confusion_matrix(ytest, ypred_xgb_sc)
#plt.title('Heatmap of Confusion Matrix', fontsize = 15)
#sns.heatmap(cm, annot = True)
#plt.show()

# %% [markdown]
# The model is giving 0% type II error and it is best.

# %% [markdown]
# # Classification Report of Model

# %%
print(classification_report(ytest, ypred_xgb_sc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        48
#            1       0.97      1.00      0.99        66
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %% [markdown]
# XGBoost model accuracy is 98.24%. It showing XGBoost is slightly overfitted but when training data will more it will generalized model.
